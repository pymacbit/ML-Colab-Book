# %% [markdown]
# <a href="https://colab.research.google.com/github/pymacbit/ML-Colab-Book/blob/master/Data%20Visualization/visualization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Importing library
import pandas as pd

# %%
# !gdown --id 1esLfoKlBE0wziIvm-bHd97FAT8ADZW_a --output iris.csv
# !gdown --id 1i42GwkEMc4YIsDdnBtk7bjvmQShVcLDH --output winemag.csv
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1esLfoKlBE0wziIvm-bHd97FAT8ADZW_a
# To: /content/iris.csv
# 100% 4.61k/4.61k [00:00<00:00, 10.3MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1i42GwkEMc4YIsDdnBtk7bjvmQShVcLDH
# To: /content/winemag.csv
# 49.8MB [00:00, 69.4MB/s]

# %%
# Importing iris dataset
iris = pd.read_csv('iris.csv', names = ['sepal_length', 'sepal_width', 'petal_lenght', 'petal_width', 'class'])
print(iris.head())
# Out:
#   sepal_length sepal_width petal_lenght petal_width        class
# 0  SepalLength  SepalWidth  PetalLength  PetalWidth      Species
# 1          5.1         3.5          1.4         0.2  Iris-setosa
# 2          4.9         3.0          1.4         0.2  Iris-setosa
# 3          4.7         3.2          1.3         0.2  Iris-setosa
# 4          4.6         3.1          1.5         0.2  Iris-setosa

# %%
# Importing wine reviews dataset

winemag = pd.read_csv('winemag.csv', index_col=0)
winemag.head()
# Out:
#   country  ...                   winery
# 0      US  ...                    Heitz
# 1   Spain  ...  Bodega Carmen Rodríguez
# 2      US  ...                 Macauley
# 3      US  ...                    Ponzi
# 4  France  ...     Domaine de la Bégude
#
# [5 rows x 10 columns]

# %%
# matplotlib
# scatter plot

import matplotlib.pyplot as plt

# %%
# create a figure and axis
fig, ax = plt.subplots()

# scatter the sepal_length against the sepal_width
ax.scatter(iris['sepal_length'], iris['sepal_width'])
# set a title and labels
ax.set_title('Iris Dataset')
ax.set_xlabel('sepal_length')
ax.set_ylabel('sepal_width')
# Out:
# Text(0, 0.5, 'sepal_width')

# %%
#lineChart

# get columns to plot
columns = iris.columns.drop(['class'])
# create x data
x_data = range(0, iris.shape[0])
# create figure and axis
fig, ax = plt.subplots()
# plot each column
for column in columns:
    ax.plot(x_data, iris[column], label=column)
# set title and legend
ax.set_title('Iris Dataset')
ax.legend()

# %%
# Histogram 

# create figure and axis
fig, ax = plt.subplots()
# plot histogram
ax.hist(winemag['points'])
# set title and labels
ax.set_title('Wine Review Scores')
ax.set_xlabel('Points')
ax.set_ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %%
#BarChart

# create a figure and axis 
fig, ax = plt.subplots() 
# count the occurrence of each class 
data = winemag['points'].value_counts() 
# get x and y data 
points = data.index 
frequency = data.values 
# create bar chart 
ax.bar(points, frequency) 
# set title and labels 
ax.set_title('Wine Review Scores') 
ax.set_xlabel('Points') 
ax.set_ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %%
# Pandas Visualization

iris.plot.scatter(x='sepal_length', y='sepal_width', title='Iris Dataset')

# %%
#histogram 
winemag['points'].plot.hist()

# %%
#barChart
winemag['points'].value_counts().sort_index().plot.bar()

# %%
winemag['points'].value_counts().sort_index().plot.barh()

# %%
winemag.groupby("country").price.mean().sort_values(ascending=False)[:5].plot.bar()

# %%
# Seaborn

import seaborn as sns
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
sns.scatterplot(x='sepal_length', y='sepal_width', data=iris)

# %%
sns.scatterplot(x='sepal_length', y='sepal_width', hue='class', data=iris)

# %%
sns.distplot(winemag['points'], bins=10, kde=False)

# %%
sns.distplot(winemag['points'], bins=10, kde=True)

# %%
sns.countplot(winemag['points'])
