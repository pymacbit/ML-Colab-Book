# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %%
# Importing Libraries
import pandas as pd
import json
import os

# %%
# To load as a list of JSON
path = "/content/drive/My Drive/dataset/NAP_Dataset"
product_json=[]
with open(path+'/netaporter_gb.json') as fp:
    for product in fp.readlines():
        product_json.append(json.loads(product))
        
# To load in a Dataframe

import pandas as pd
data = pd.read_json("/content/drive/My Drive/dataset/NAP_Dataset/netaporter_gb.json",lines=True,orient='columns')

# %%
data[:5]
# Out:
#                                     _id  ... sizes
# 0  {'$oid': '5da822166504fb65da005a59'}  ...   NaN
# 1  {'$oid': '5da822607d3a9baa211f85f4'}  ...   NaN
# 2  {'$oid': '5da8221a6504fb65da005a7b'}  ...   NaN
# 3  {'$oid': '5da8218b6504fb65da004fb2'}  ...   NaN
# 4  {'$oid': '5da823b76504fb65cb261ac9'}  ...   NaN
#
# [5 rows x 22 columns]
