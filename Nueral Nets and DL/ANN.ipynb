# %%
# Importing the libraries 
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
dataset = pd.read_csv('CM.csv')
X = dataset.iloc[:,3:13].values
y = dataset.iloc[:,13].values

# %%
dataset.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# 4         79084.10       0

# %%
# Taking care of Categoricial data

from sklearn.preprocessing import LabelEncoder, OneHotEncoder

labelencoder_X_1 = LabelEncoder()
X[:,1] = labelencoder_X_1.fit_transform(X[:,1])

labelencoder_X_2 = LabelEncoder()
X[:,2] = labelencoder_X_2.fit_transform(X[:,2])



from sklearn.compose import ColumnTransformer

# Country column
onehotencoder = ColumnTransformer([("Geography", OneHotEncoder(), [1])], remainder = 'passthrough')
X = onehotencoder.fit_transform(X)
X = X[:,1:]

# %%
# Splitting the dataset into Training set and Test set
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.2 ,random_state = 0)

# %%
# Feature Scaling
from sklearn.preprocessing import StandardScaler
sc_X = StandardScaler()
X_train = sc_X.fit_transform(X_train)
X_test = sc_X.transform(X_test)

# %%
# Importing the keras libraries and required packages
import keras 
from keras.models import Sequential
from keras.layers import Dense

# Initialising the ANN
classifier = Sequential()

# Adding the input layer and the first hidden layer
classifier.add(Dense(output_dim = 6, init = 'uniform', activation = 'relu', input_dim = 11))
 
# Adding the second hidden layer
classifier.add(Dense(output_dim = 6, init = 'uniform', activation = 'relu'))

# Adding the output layer
classifier.add(Dense(output_dim = 1, init = 'uniform', activation = 'sigmoid'))

# Compiling the ANN
classifier.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['accuracy'] )
# Out:
# Using TensorFlow backend.
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:10: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(activation="relu", input_dim=11, units=6, kernel_initializer="uniform")`
#   # Remove the CWD from sys.path while we load stuff.
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(activation="relu", units=6, kernel_initializer="uniform")`
#   del sys.path[0]
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:16: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(activation="sigmoid", units=1, kernel_initializer="uniform")`
#   app.launch_new_instance()

# %%
# Fitting the ANN to the training set 
classifier.fit(X_train, y_train, batch_size = 10, epochs = 100)
# Out:
# Epoch 1/100
# 8000/8000 [==============================] - 1s 177us/step - loss: 0.4981 - accuracy: 0.7952
# Epoch 2/100
# 8000/8000 [==============================] - 1s 140us/step - loss: 0.4301 - accuracy: 0.7960
# Epoch 3/100
# 8000/8000 [==============================] - 1s 146us/step - loss: 0.4257 - accuracy: 0.7960
# Epoch 4/100
# 8000/8000 [==============================] - 1s 150us/step - loss: 0.4221 - accuracy: 0.7966
# Epoch 5/100
# 8000/8000 [==============================] - 1s 137us/step - loss: 0.4191 - accuracy: 0.8202
# Epoch 6/100
# 8000/8000 [==============================] - 1s 140us/step - loss: 0.4172 - accuracy: 0.8250
# Epoch 7/100
# 8000/8000 [==============================] - 1s 143us/step - loss: 0.4148 - accuracy: 0.8299
# Epoch 8/100
# 8000/8000 [==============================] - 1s 145us/step - loss: 0.4136 - accuracy: 0.8296
# Epoch 9/100
# 8000/8000 [==============================] - 1s 146us/step - loss: 0.4120 - accuracy: 0.8315
# Epoch 10/100
# 8000/8000 [==============================] - 1s 137us/step - loss: 0.4113 - accuracy: 0.8317
# Epoch 11/100
# 8000/8000 [==============================] - 1s 135us/step - loss: 0.4102 - accuracy: 0.8332
# Epoch 12/100
# 8000/8000 [==============================] - 1s 126us/step - loss: 0.4088 - accuracy: 0.8339
# Epoch 13/100
# 8000/8000 [==============================] - 1s 129us/step - loss: 0.4088 - accuracy: 0.8344
# Epoch 14/100
# 8000/8000 [==============================] - 1s 131us/step - loss: 0.4077 - accuracy: 0.8338
# Epoch 15/100
# 8000/8000 [==============================] - 1s 129us/step - loss: 0.4071 - accuracy: 0.8347
# Epoch 16/100
# 8000/8000 [==============================] - 1s 136us/step - loss: 0.4067 - accuracy: 0.8344
# Epoch 17/100
# 8000/8000 [==============================] - 1s 133us/step - loss: 0.4061 - accuracy: 0.8341
# Epoch 18/100
# 8000/8000 [==============================] - 1s 134us/step - loss: 0.4059 - accuracy: 0.8334
# Epoch 19/100
# 8000/8000 [==============================] - 1s 145us/step - loss: 0.4047 - accuracy: 0.8344
# Epoch 20/100
# 8000/8000 [==============================] - 1s 138us/step - loss: 0.4050 - accuracy: 0.8342
# Epoch 21/100
# 8000/8000 [==============================] - 1s 136us/step - loss: 0.4047 - accuracy: 0.8356
# Epoch 22/100
# 8000/8000 [==============================] - 1s 135us/step - loss: 0.4045 - accuracy: 0.8340
# Epoch 23/100
# 8000/8000 [==============================] - 1s 144us/step - loss: 0.4040 - accuracy: 0.8340
# Epoch 24/100
# 8000/8000 [==============================] - 1s 135us/step - loss: 0.4041 - accuracy: 0.8345
# Epoch 25/100
# 8000/8000 [==============================] - 1s 134us/step - loss: 0.4034 - accuracy: 0.8346
# Epoch 26/100
# 8000/8000 [==============================] - 1s 136us/step - loss: 0.4034 - accuracy: 0.8350
# Epoch 27/100
# 8000/8000 [==============================] - 1s 151us/step - loss: 0.4032 - accuracy: 0.8366
# Epoch 28/100
# 8000/8000 [==============================] - 1s 149us/step - loss: 0.4030 - accuracy: 0.8335
# Epoch 29/100
# 8000/8000 [==============================] - 1s 157us/step - loss: 0.4027 - accuracy: 0.8357
# Epoch 30/100
# 8000/8000 [==============================] - 1s 147us/step - loss: 0.4023 - accuracy: 0.8344
# Epoch 31/100
# 8000/8000 [==============================] - 1s 147us/step - loss: 0.4026 - accuracy: 0.8341
# Epoch 32/100
# 8000/8000 [==============================] - 1s 158us/step - loss: 0.4024 - accuracy: 0.8349
# Epoch 33/100
# 8000/8000 [==============================] - 1s 178us/step - loss: 0.4016 - accuracy: 0.8351
# Epoch 34/100
# 8000/8000 [==============================] - 1s 155us/step - loss: 0.4021 - accuracy: 0.8350
# Epoch 35/100
# 8000/8000 [==============================] - 1s 128us/step - loss: 0.4019 - accuracy: 0.8342
# Epoch 36/100
# 8000/8000 [==============================] - 1s 132us/step - loss: 0.4020 - accuracy: 0.8346
# Epoch 37/100
# 8000/8000 [==============================] - 1s 139us/step - loss: 0.4017 - accuracy: 0.8346
# Epoch 38/100
# 8000/8000 [==============================] - 1s 126us/step - loss: 0.4014 - accuracy: 0.8356
# Epoch 39/100
# 8000/8000 [==============================] - 1s 149us/step - loss: 0.4010 - accuracy: 0.8342
# Epoch 40/100
# 8000/8000 [==============================] - 1s 133us/step - loss: 0.4012 - accuracy: 0.8351
# Epoch 41/100
# 8000/8000 [==============================] - 1s 140us/step - loss: 0.4009 - accuracy: 0.8356
# Epoch 42/100
# 8000/8000 [==============================] - 1s 162us/step - loss: 0.4012 - accuracy: 0.8360
# Epoch 43/100
# 8000/8000 [==============================] - 1s 128us/step - loss: 0.4013 - accuracy: 0.8336
# Epoch 44/100
# 8000/8000 [==============================] - 1s 132us/step - loss: 0.4008 - accuracy: 0.8351
# Epoch 45/100
# 8000/8000 [==============================] - 1s 155us/step - loss: 0.4008 - accuracy: 0.8353
# Epoch 46/100
# 8000/8000 [==============================] - 1s 152us/step - loss: 0.4010 - accuracy: 0.8359
# Epoch 47/100
# 8000/8000 [==============================] - 1s 158us/step - loss: 0.4008 - accuracy: 0.8334
# Epoch 48/100
# 8000/8000 [==============================] - 1s 152us/step - loss: 0.4006 - accuracy: 0.8342
# Epoch 49/100
# 8000/8000 [==============================] - 1s 138us/step - loss: 0.4009 - accuracy: 0.8347
# Epoch 50/100
# 8000/8000 [==============================] - 1s 160us/step - loss: 0.4005 - accuracy: 0.8350
# Epoch 51/100
# 8000/8000 [==============================] - 1s 156us/step - loss: 0.4004 - accuracy: 0.8361
# Epoch 52/100
# 8000/8000 [==============================] - 1s 170us/step - loss: 0.4006 - accuracy: 0.8341
# Epoch 53/100
# 8000/8000 [==============================] - 1s 150us/step - loss: 0.4006 - accuracy: 0.8346
# Epoch 54/100
# 8000/8000 [==============================] - 1s 152us/step - loss: 0.4004 - accuracy: 0.8350
# Epoch 55/100
# 8000/8000 [==============================] - 1s 166us/step - loss: 0.4001 - accuracy: 0.8344
# Epoch 56/100
# 8000/8000 [==============================] - 1s 141us/step - loss: 0.4002 - accuracy: 0.8331
# Epoch 57/100
# 8000/8000 [==============================] - 1s 150us/step - loss: 0.4005 - accuracy: 0.8354
# Epoch 58/100
# 8000/8000 [==============================] - 1s 143us/step - loss: 0.4003 - accuracy: 0.8344
# Epoch 59/100
# 8000/8000 [==============================] - 1s 157us/step - loss: 0.4002 - accuracy: 0.8353
# Epoch 60/100
# 8000/8000 [==============================] - 1s 142us/step - loss: 0.3996 - accuracy: 0.8355
# Epoch 61/100
# 8000/8000 [==============================] - 1s 146us/step - loss: 0.4003 - accuracy: 0.8353
# Epoch 62/100
# 8000/8000 [==============================] - 1s 160us/step - loss: 0.4001 - accuracy: 0.8361
# Epoch 63/100
# 8000/8000 [==============================] - 1s 149us/step - loss: 0.4002 - accuracy: 0.8342
# Epoch 64/100
# 8000/8000 [==============================] - 1s 151us/step - loss: 0.3999 - accuracy: 0.8347
# Epoch 65/100
# 8000/8000 [==============================] - 1s 144us/step - loss: 0.3996 - accuracy: 0.8355
# Epoch 66/100
# 8000/8000 [==============================] - 1s 135us/step - loss: 0.4002 - accuracy: 0.8351
# Epoch 67/100
# 8000/8000 [==============================] - 1s 133us/step - loss: 0.4000 - accuracy: 0.8345
# Epoch 68/100
# 8000/8000 [==============================] - 1s 133us/step - loss: 0.4002 - accuracy: 0.8341
# Epoch 69/100
# 8000/8000 [==============================] - 1s 132us/step - loss: 0.4001 - accuracy: 0.8354
# Epoch 70/100
# 8000/8000 [==============================] - 1s 178us/step - loss: 0.4001 - accuracy: 0.8353
# Epoch 71/100
# 8000/8000 [==============================] - 1s 145us/step - loss: 0.3997 - accuracy: 0.8347
# Epoch 72/100
# 8000/8000 [==============================] - 1s 142us/step - loss: 0.4000 - accuracy: 0.8357
# Epoch 73/100
# 8000/8000 [==============================] - 1s 134us/step - loss: 0.3999 - accuracy: 0.8339
# Epoch 74/100
# 8000/8000 [==============================] - 1s 133us/step - loss: 0.3999 - accuracy: 0.8357
# Epoch 75/100
# 8000/8000 [==============================] - 1s 135us/step - loss: 0.3997 - accuracy: 0.8339
# Epoch 76/100
# 8000/8000 [==============================] - 1s 136us/step - loss: 0.4002 - accuracy: 0.8344
# Epoch 77/100
# 8000/8000 [==============================] - 1s 136us/step - loss: 0.4000 - accuracy: 0.8332
# Epoch 78/100
# 8000/8000 [==============================] - 1s 133us/step - loss: 0.4003 - accuracy: 0.8350
# Epoch 79/100
# 8000/8000 [==============================] - 1s 158us/step - loss: 0.4000 - accuracy: 0.8347
# Epoch 80/100
# 8000/8000 [==============================] - 1s 133us/step - loss: 0.3995 - accuracy: 0.8354
# Epoch 81/100
# 8000/8000 [==============================] - 1s 139us/step - loss: 0.4003 - accuracy: 0.8357
# Epoch 82/100
# 8000/8000 [==============================] - 1s 136us/step - loss: 0.3999 - accuracy: 0.8355
# Epoch 83/100
# 8000/8000 [==============================] - 1s 135us/step - loss: 0.3995 - accuracy: 0.8347
# Epoch 84/100
# 8000/8000 [==============================] - 1s 135us/step - loss: 0.3999 - accuracy: 0.8347
# Epoch 85/100
# 8000/8000 [==============================] - 1s 133us/step - loss: 0.3997 - accuracy: 0.8363
# Epoch 86/100
# 8000/8000 [==============================] - 1s 132us/step - loss: 0.3996 - accuracy: 0.8360
# Epoch 87/100
# 8000/8000 [==============================] - 1s 135us/step - loss: 0.4001 - accuracy: 0.8354
# Epoch 88/100
# 8000/8000 [==============================] - 1s 135us/step - loss: 0.3997 - accuracy: 0.8341
# Epoch 89/100
# 8000/8000 [==============================] - 1s 137us/step - loss: 0.3996 - accuracy: 0.8342
# Epoch 90/100
# 8000/8000 [==============================] - 1s 134us/step - loss: 0.3995 - accuracy: 0.8355
# Epoch 91/100
# 8000/8000 [==============================] - 1s 134us/step - loss: 0.3996 - accuracy: 0.8366
# Epoch 92/100
# 8000/8000 [==============================] - 1s 137us/step - loss: 0.3993 - accuracy: 0.8342
# Epoch 93/100
# 8000/8000 [==============================] - 1s 135us/step - loss: 0.3997 - accuracy: 0.8335
# Epoch 94/100
# 8000/8000 [==============================] - 1s 136us/step - loss: 0.3995 - accuracy: 0.8360
# Epoch 95/100
# 8000/8000 [==============================] - 1s 136us/step - loss: 0.3992 - accuracy: 0.8336
# Epoch 96/100
# 8000/8000 [==============================] - 1s 144us/step - loss: 0.3993 - accuracy: 0.8357
# Epoch 97/100
# 8000/8000 [==============================] - 1s 135us/step - loss: 0.3995 - accuracy: 0.83530s
# Epoch 98/100
# 8000/8000 [==============================] - 1s 135us/step - loss: 0.3998 - accuracy: 0.8340
# Epoch 99/100
# 8000/8000 [==============================] - 1s 137us/step - loss: 0.3995 - accuracy: 0.8347
# Epoch 100/100
# 8000/8000 [==============================] - 1s 139us/step - loss: 0.3997 - accuracy: 0.8353

# %%
# Predicting the tests set results
y_pred = classifier.predict(X_test)
y_pred = (y_pred > 0.5)

# %%
# Making the Confusion Matrix
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, y_pred)

# %%
# Accuracy using confusion matrix
accuracy_per = ((cm[0,0]+cm[1,1])/len(y_test))
print(accuracy_per * 100)
# Out:
# 84.2
